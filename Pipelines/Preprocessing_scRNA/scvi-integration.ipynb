# %% [markdown]
# # Load Python Modules

# %%
import anndata
import scanpy as sc
import scvi
import scvelo as scv
import pandas as pd
from time import gmtime, strftime
import os
strftime("%Y-%m-%d %H:%M:%S", gmtime())
# Out:
# Global seed set to 0
# '2022-08-04 02:45:08'

# %%
mainDir = "/mnt/gmi-analysis01/_90.User_Data/juhyunk/project/schizophrenia/scRNA/singleCellAnalysis_byLibrary/"

# %%
date = '2022-07-29'

# %%
library_dict = ["CTR01",
                "CTR03",
                "CTR05",
                "CTR07",
                "GHR06",
                "GHR11",
                "GHR12",
                "GHR13",
                "SPR01",
                "SPR03",
                "SPR04",
                "SPR06"]

# %%
library = library_dict[0]
print(library)

adata0 = sc.read_h5ad(mainDir + library + '/cellbender/' + library + '.Cellbender.h5ad')
adata0.var_names_make_unique()

# merge results of doubletFinder
doubletFinderMeta = pd.read_table(mainDir + library + "/DoubletFinder/" + library + ".DoubletFinder.metaData.txt",
                        sep = '\t')
adata0.obs = adata0.obs.join(doubletFinderMeta, lsuffix='_cellbender', rsuffix='_doubletFinder')
adata0.obs.index = library + ":" + adata0.obs.index
adata0 = adata0[adata0.obs["doubletFinder_result"]=="Singlet"]
del library_dict[0]
adata0
# Out:
# CTR01
# View of AnnData object with n_obs × n_vars = 5489 × 36601
#     obs: 'orig.ident_cellbender', 'nCount_RNA_cellbender', 'nFeature_RNA_cellbender', 'orig.ident_doubletFinder', 'nCount_RNA_doubletFinder', 'nFeature_RNA_doubletFinder', 'percent.mt', 'percent.ribo', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.3', 'seurat_clusters', 'doubletFinder_pANN', 'doubletFinder_result'
#     var: 'features'

# %%
for library in library_dict :
    print("library = "+library)
    
    adata1 = sc.read_h5ad(mainDir + library + '/cellbender/' + library + '.Cellbender.h5ad')
    adata1.var_names_make_unique()

    # merge results of doubletFinder
    doubletFinderMeta = pd.read_table(mainDir + library + "/DoubletFinder/" + library + ".DoubletFinder.metaData.txt",
                            sep = '\t')
    adata1.obs = adata1.obs.join(doubletFinderMeta, lsuffix='_cellbender', rsuffix='_doubletFinder')
    adata1.obs.index = library + ":" + adata1.obs.index
    adata1 = adata1[adata1.obs["doubletFinder_result"]=="Singlet"]

    # concatenate the adata
    adata0 = adata0.concatenate(adata1, index_unique=None)
# Out:
# library = CTR03
# library = CTR05
# library = CTR07
# library = GHR06
# library = GHR11
# library = GHR12
# library = GHR13
# library = SPR01
# library = SPR03
# library = SPR04
# library = SPR06

# %%
adata = adata0

# %%
del adata0, adata1,doubletFinderMeta

# %%
os.makedirs(mainDir + "scvi_integrated/" + strftime("%Y-%m-%d",gmtime()) + "/scanpy", exist_ok=True)

# %%
adata.write_h5ad(
          mainDir + "scvi_integrated/" + strftime("%Y-%m-%d",gmtime()) + "/scanpy/rawAnndata.h5ad")

# %%
adata.var_names = adata.var["features"]

adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# ribosomal genes
adata.var['ribo'] = adata.var_names.str.startswith(("RPS","RPL"))
sc.pp.calculate_qc_metrics(adata, qc_vars=['ribo'], percent_top=None, log1p=False, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 76792 × 36601
#     obs: 'orig.ident_cellbender', 'nCount_RNA_cellbender', 'nFeature_RNA_cellbender', 'orig.ident_doubletFinder', 'nCount_RNA_doubletFinder', 'nFeature_RNA_doubletFinder', 'percent.mt', 'percent.ribo', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.3', 'seurat_clusters', 'doubletFinder_pANN', 'doubletFinder_result', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'features', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'ribo'

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=False, groupby="orig.ident_doubletFinder")
# sc.pl.stacked_violin(adata,  ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], groupby="batch",dendrogram=True)

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt', groups="orig.ident_doubletFinder")
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs.n_genes_by_counts > 100, 0:]
adata = adata[adata.obs.total_counts < 100000, :]
adata = adata[adata.obs.pct_counts_mt < 10, :]

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt','pct_counts_ribo'],
             jitter=0.4, multi_panel=False, groupby="orig.ident_doubletFinder")
# sc.pl.stacked_violin(adata,  ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], groupby="batch",dendrogram=True)

# %%
adata.obs.groupby("orig.ident_doubletFinder").count()["orig.ident_cellbender"]
# Out:
# orig.ident_doubletFinder
# CTR01     5489
# CTR03     7929
# CTR05     1072
# CTR07     7142
# GHR06     7863
# GHR11    10244
# GHR12     5731
# GHR13     3717
# SPR01     6845
# SPR03     9616
# SPR04     5997
# SPR06     5147
# Name: orig.ident_cellbender, dtype: int64

# %%
adata.layers["counts"] = adata.X.copy() # preserve counts
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

adata.raw = adata # freeze the state in '.raw'

# %%
sc.pp.highly_variable_genes(
    adata,
    n_top_genes=10000,
    subset=True,
    layer="counts",
    flavor="seurat_v3", # for seurat_v3, it use dispersion-based methods
    batch_key="orig.ident_doubletFinder"
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 76792 × 10000
#     obs: 'orig.ident_cellbender', 'nCount_RNA_cellbender', 'nFeature_RNA_cellbender', 'orig.ident_doubletFinder', 'nCount_RNA_doubletFinder', 'nFeature_RNA_doubletFinder', 'percent.mt', 'percent.ribo', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.3', 'seurat_clusters', 'doubletFinder_pANN', 'doubletFinder_result', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'features', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'ribo', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'orig.ident_doubletFinder_colors', 'log1p', 'hvg'
#     layers: 'counts'

# %%
import numpy as np

# %%
adata.obs["log_nCount_RNA"] = np.log1p(adata.obs["nCount_RNA_doubletFinder"])

# %%
scvi.model.SCVI.setup_anndata(adata,
                              layer="counts",
                              categorical_covariate_keys= ["orig.ident_doubletFinder"],
                              continuous_covariate_keys = ["pct_counts_mt"])

# %%
vae = scvi.model.SCVI(adata, n_latent=50, n_layers=3, dropout_rate=0.1, dispersion="gene")

# %%
vae.train(use_gpu = True)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 104/104: 100%|██████████| 104/104 [17:54<00:00, 10.33s/it, loss=4.83e+03, v_num=1]

# %%
vae
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 50, n_layers: 3, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Trained

# %%
vae.save(mainDir + "/scvi_integrated/" + strftime("%Y-%m-%d %H:%M:%S", gmtime()) + "/scviModel/" )

# %% [markdown]
# ## Obtaining model output

# %%
adata.obsm["X_scVI"] = vae.get_latent_representation()

# %%
adata.layers["scvi_normalized"] = vae.get_normalized_expression(
    library_size=10e4
)

# %% [markdown]
# # Interoperability with Scanpy

# %% [markdown]
# ## Visualization with batch correction (scVI)

# %%
# use scVI latent space for UMAP generation
sc.pp.neighbors(adata, use_rep="X_scVI
                ")
sc.tl.umap(adata, min_dist=0.3)

# %%
sc.pl.umap(
    adata,
    color=["orig.ident_doubletFinder"],
    frameon=False,
    size = 10,
    sort_order = False,
    title = "Umap by Sample"
)

# %%
adata.obs["condition"] = adata.obs["orig.ident_doubletFinder"].str.slice(0,3)

# %%
sc.pl.umap(
    adata,
    color=["condition"],
    frameon=False,
    size = 10,
    sort_order = False,
    title = "Umap by Condition"
)

# %%
sc.pl.umap(adata, color="condition", size = 10 , groups = "CTR")

# %%
sc.pl.umap(adata, color="condition", size = 10, groups = "SPR")

# %%
sc.pl.umap(adata, color="condition", size = 10, groups = "GHR")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 76792 × 10000
#     obs: 'orig.ident_cellbender', 'nCount_RNA_cellbender', 'nFeature_RNA_cellbender', 'orig.ident_doubletFinder', 'nCount_RNA_doubletFinder', 'nFeature_RNA_doubletFinder', 'percent.mt', 'percent.ribo', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.3', 'seurat_clusters', 'doubletFinder_pANN', 'doubletFinder_result', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', '_scvi_batch', '_scvi_labels', 'condition'
#     var: 'features', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'ribo', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'orig.ident_doubletFinder_colors', 'log1p', 'hvg', '_scvi_uuid', '_scvi_manager_uuid', 'neighbors', 'umap', 'condition_colors'
#     obsm: '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs', 'X_scVI', 'X_umap'
#     layers: 'counts', 'scvi_normalized'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# ## Clustering on the scVI latent space

# %%
res = 1.0

# %%
# neighbors were already computed using scVI
sc.tl.louvain(adata, key_added="louvain_scVI_" + str(res), resolution= res)

# %%
sc.pl.umap(
    adata,
    color=["louvain_scVI_"+ str(res)],
    frameon=False,
)

# %%
adata.write_h5ad(
          mainDir + "scvi_integrated/" + strftime("%Y-%m-%d",gmtime()) + "/scanpy/scvi_integrated.h5ad")

# %%
import math

import natsort
import pandas
import session_info


session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# anndata             0.8.0
# natsort             8.1.0
# numpy               1.21.6
# pandas              1.4.1
# scanpy              1.9.1
# scvelo              0.2.4
# scvi                0.16.4
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         9.1.1
# absl                        NA
# asttokens                   NA
# attr                        21.4.0
# backcall                    0.2.0
# beta_ufunc                  NA
# binom_ufunc                 NA
# brotli                      NA
# certifi                     2022.06.15
# cffi                        1.15.0
# charset_normalizer          2.0.4
# chex                        0.1.3
# colorama                    0.4.4
# cycler                      0.10.0
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.5.1
# decorator                   5.1.1
# defusedxml                  0.7.1
# deprecate                   0.3.1
# docrep                      0.3.2
# entrypoints                 0.4
# executing                   0.8.3
# flatbuffers                 2.0
# flax                        0.5.0
# fsspec                      2022.5.0
# google                      NA
# h5py                        3.6.0
# hypergeom_ufunc             NA
# idna                        3.3
# igraph                      0.9.11
# importlib_metadata          NA
# ipykernel                   6.9.1
# ipython_genutils            0.2.0
# ipywidgets                  7.7.0
# jax                         0.3.13
# jaxlib                      0.3.10
# jedi                        0.18.1
# joblib                      1.1.0
# jupyter_server              1.17.1
# kiwisolver                  1.4.3
# leidenalg                   0.8.10
# llvmlite                    0.38.1
# louvain                     0.7.1
# matplotlib                  3.5.2
# matplotlib_inline           NA
# mpl_toolkits                NA
# msgpack                     1.0.4
# multipledispatch            0.6.0
# nbinom_ufunc                NA
# networkx                    2.8.3
# numba                       0.55.1
# numpyro                     0.9.2
# opt_einsum                  v3.3.0
# optax                       0.0.9
# packaging                   21.3
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# prompt_toolkit              3.0.20
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.6.0
# pydevd_concurrency_analyser NA
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.11.2
# pynndescent                 0.5.7
# pyparsing                   3.0.9
# pyro                        1.8.1+06911dc
# pytorch_lightning           1.5.8
# pytz                        2022.1
# requests                    2.27.1
# rich                        NA
# scipy                       1.8.1
# seaborn                     0.11.2
# setuptools                  62.4.0
# six                         1.16.0
# sklearn                     1.1.1
# skmisc                      0.1.4
# socks                       1.7.1
# sphinxcontrib               NA
# stack_data                  0.2.0
# statsmodels                 0.13.2
# tensorboard                 2.9.0
# texttable                   1.6.4
# threadpoolctl               3.1.0
# toolz                       0.11.2
# torch                       1.11.0
# torchmetrics                0.9.1
# torchvision                 0.12.0
# tornado                     6.1
# tqdm                        4.64.0
# traitlets                   5.1.1
# tree                        0.1.7
# typing_extensions           NA
# umap                        0.5.3
# unicodedata2                NA
# urllib3                     1.26.9
# wcwidth                     0.2.5
# wrapt                       1.14.1
# yaml                        6.0
# zipp                        NA
# zmq                         22.3.0
# zope                        NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.3.0
# jupyter_client      7.2.2
# jupyter_core        4.10.0
# jupyterlab          3.4.3
# notebook            6.4.11
# -----
# Python 3.9.12 | packaged by conda-forge | (main, Mar 24 2022, 23:25:59) [GCC 10.3.0]
# Linux-3.10.0-1160.el7.x86_64-x86_64-with-glibc2.17
# -----
# Session information updated at 2022-07-30 13:40
# </pre>
# </details>

# %% [markdown]
# # Differential expression

# %%
adata = sc.read_h5ad(mainDir + "scvi_integrated/" + date + "/scanpy/scvi_integrated.velocyto.cellcycle.3Dumap.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 73352 × 10000
#     obs: 'orig.ident_cellbender', 'nCount_RNA_cellbender', 'nFeature_RNA_cellbender', 'orig.ident_doubletFinder', 'nCount_RNA_doubletFinder', 'nFeature_RNA_doubletFinder', 'percent.mt', 'percent.ribo', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.3', 'seurat_clusters', 'doubletFinder_pANN', 'doubletFinder_result', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'log_nCount_RNA', '_scvi_batch', '_scvi_labels', 'condition', 'louvain_scVI_1.0', 'sample', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'Cluster', 'S_score', 'G2M_score', 'phase', 'phate_tail'
#     var: 'features', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'ribo', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches', 'Accession', 'Chromosome', 'End', 'Start', 'Strand'
#     uns: 'Cluster_colors', '_scvi_manager_uuid', '_scvi_uuid', 'condition_colors', 'hvg', 'log1p', 'louvain', 'louvain_scVI_1.0_colors', 'neighbors', 'orig.ident_doubletFinder_colors', 'phase_colors', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs'
#     layers: 'ambiguous', 'counts', 'matrix', 'scvi_normalized', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
# vae.save(mainDir + "/scvi_integrated/" + strftime("%Y-%m-%d %H:%M:%S", gmtime()) + "/scviModel/" )
model = scvi.model.SCVI.load("/mnt/gmi-analysis01/_90.User_Data/juhyunk/project/schizophrenia/scRNA/singleCellAnalysis_byLibrary//scvi_integrated/2022-07-29/scanpy/", adata=adata, use_gpu=True)
# model = scvi.model.SCVI.load(mainDir + "/scvi_integrated/" + date + "/scviModel/", adata=adata, use_gpu=True)
# Out:
# INFO     File /mnt/gmi-analysis01/_90.User_Data/juhyunk/project/schizophrenia/scRNA/singleCel
#          lAnalysis_byLibrary//scvi_integrated/2022-07-29/scanpy/model.pt already downloaded

# %%
model
# Out:
# SCVI Model with the following params:
# n_hidden: 128, n_latent: 50, n_layers: 3, dropout_rate: 0.1, dispersion: gene,
# gene_likelihood: zinb, latent_distribution: normal
# Training status: Trained

# %%
de_df = model.differential_expression(
    groupby="condition",
    group1="GHR",
    group2="CTR"
)
# Out:
# DE...: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:15<00:00, 15.63s/it]

# %%
de_df.head()
# Out:
#           proba_de  proba_not_de  bayes_factor    scale1        scale2  \
# features
# PPP1R1B     0.9612        0.0388      3.209762  0.000002  5.685869e-07
# SLC35F1     0.9602        0.0398      3.183274  0.000117  7.157495e-04
# LERFS       0.9582        0.0418      3.132160  0.000002  1.597257e-05
# NKD2        0.9490        0.0510      2.923583  0.000002  8.560236e-06
# APOD        0.9440        0.0560      2.824774  0.000195  4.901363e-04
#
#           pseudocounts  delta  lfc_mean  lfc_median   lfc_std  ...  raw_mean1  \
# features                                                       ...
# PPP1R1B            0.0   0.25  1.714055    1.703503  1.021133  ...   0.012064
# SLC35F1            0.0   0.25 -4.015515   -4.225247  1.929328  ...   1.744427
# LERFS              0.0   0.25 -2.575450   -2.709818  1.390087  ...   0.001877
# NKD2               0.0   0.25 -1.715147   -2.163445  2.202389  ...   0.003677
# APOD               0.0   0.25 -0.931451   -1.317770  2.305860  ...   2.646687
#
#           raw_mean2  non_zeros_proportion1  non_zeros_proportion2  \
# features
# PPP1R1B    0.000249               0.010762               0.000249
# SLC35F1    9.024969               0.216507               0.977618
# LERFS      0.153992               0.001838               0.129371
# NKD2       0.059140               0.003370               0.052375
# APOD       4.814673               0.697511               0.771151
#
#           raw_normalized_mean1  raw_normalized_mean2  is_de_fdr_0.05  \
# features
# PPP1R1B               0.007509              0.000177            True
# SLC35F1               0.930432              7.124952            True
# LERFS                 0.001666              0.136539            True
# NKD2                  0.003814              0.063991            True
# APOD                  2.071301              4.957573            True
#
#           comparison  group1 group2
# features
# PPP1R1B   GHR vs CTR     GHR    CTR
# SLC35F1   GHR vs CTR     GHR    CTR
# LERFS     GHR vs CTR     GHR    CTR
# NKD2      GHR vs CTR     GHR    CTR
# APOD      GHR vs CTR     GHR    CTR
#
# [5 rows x 22 columns]

# %%
de_df.to_csv("/gmi-l1/_90.User_Data/juhyunk/GHRvsCTR.txt")

# %%
import matplotlib.pyplot as plt
import numpy as np

from adjustText import adjust_text
from faker import Faker
from palmerpenguins import load_penguins

################################
# Colors
BG_WHITE = "#fbf9f4"
GREY_LIGHT = "#b4aea9"
GREY50 = "#7F7F7F"
GREY30 = "#4d4d4d"
BLUE_DARK = "#1B2838"
BLUE = "#2a475e"
COLORS = ["#386cb0", "#fdb462", "#7fc97f" ] # A color for each species
################################

# Generate Faker instance and set seed or reproducibility
faker = Faker()
# Set seed for reproducibility of the random names
faker.seed_instance(11) 
#################################

fig, ax = plt.subplots(figsize= (14, 10))
ax.scatter(de_df['lfc_mean'],de_df['bayes_factor'], c=de_df['is_de_fdr_0.05'],
           cmap="Greens", edgecolor = 'gray', s=de_df['raw_normalized_mean1'])
topNum = 20


de_text = de_df.loc[de_df['is_de_fdr_0.05'] == True, ].sort_values(by=['raw_normalized_mean1'],ascending=False)
labels = de_text.index[0:topNum]
for label, x, y in zip(labels, de_text.lfc_mean[0:topNum], de_text.bayes_factor[0:topNum]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-20, 20),
        textcoords='offset points', ha='right', va='bottom',
         bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.ylabel('Bayes Factor', fontweight='bold', fontsize = 15)
plt.xlabel('log FC', fontweight='bold', fontsize = 15)
plt.title("Schizophrenia Specific cluster DEG", fontsize = 20,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Schizophrenia Specific cluster DEG')

# %%
de_df["normMax"] = de_df[["raw_normalized_mean1","raw_normalized_mean2"]].max(axis=1)

# %%
import matplotlib.pyplot as plt
import numpy as np

from adjustText import adjust_text
from faker import Faker
from palmerpenguins import load_penguins

################################
# Colors
BG_WHITE = "#fbf9f4"
GREY_LIGHT = "#b4aea9"
GREY50 = "#7F7F7F"
GREY30 = "#4d4d4d"
BLUE_DARK = "#1B2838"
BLUE = "#2a475e"
COLORS = ["#386cb0", "#fdb462", "#7fc97f" ] # A color for each species
################################

# Generate Faker instance and set seed or reproducibility
faker = Faker()
# Set seed for reproducibility of the random names
faker.seed_instance(11) 
#################################

fig, ax = plt.subplots(figsize= (14, 10))
ax.scatter(de_df['lfc_mean'],de_df['bayes_factor'], c=de_df['is_de_fdr_0.05'],
           cmap="Greens", edgecolor = 'gray', s=de_df['raw_normalized_mean1'])
topNum = 20


de_text = de_df.loc[de_df['is_de_fdr_0.05'] == True, ].sort_values(by=['normMax'],ascending=False)
labels = de_df.index[0:topNum]
for label, x, y in zip(labels, de_df.lfc_mean[0:topNum], de_df.bayes_factor[0:topNum]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-20, 20),
        textcoords='offset points', ha='right', va='bottom',
         bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

plt.ylabel('Bayes Factor', fontweight='bold', fontsize = 15)
plt.xlabel('log FC', fontweight='bold', fontsize = 15)
plt.title("Schizophrenia Specific cluster DEG", fontsize = 20,fontweight='bold')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [84], in <cell line: 31>()
#      26 ax.scatter(de_df['lfc_mean'],de_df['bayes_factor'], c=de_df['is_de_fdr_0.05'],
#      27            cmap="Greens", edgecolor = 'gray', s=de_df['raw_normalized_mean1'])
#      28 topNum = 20
# ---> 31 de_text = de_df.loc[de_df['is_de_fdr_0.05'] == True, ].sort_values(by=['normMax'],ascending=False)
#      32 labels = de_df.index[0:topNum]
#      33 for label, x, y in zip(labels, de_df.lfc_mean[0:topNum], de_df.bayes_factor[0:topNum]):
#
# File ~/anaconda3/envs/scRNA_python/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/scRNA_python/lib/python3.9/site-packages/pandas/core/frame.py:6307, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6303 elif len(by):
#    6304     # len(by) == 1
#    6306     by = by[0]
# -> 6307     k = self._get_label_or_level_values(by, axis=axis)
#    6309     # need to rewrap column in Series to apply key function
#    6310     if key is not None:
#    6311         # error: Incompatible types in assignment (expression has type
#    6312         # "Series", variable has type "ndarray")
#
# File ~/anaconda3/envs/scRNA_python/lib/python3.9/site-packages/pandas/core/generic.py:1848, in NDFrame._get_label_or_level_values(self, key, axis)
#    1846     values = self.axes[axis].get_level_values(key)._values
#    1847 else:
# -> 1848     raise KeyError(key)
#    1850 # Check for duplicates
#    1851 if values.ndim > 1:
#
# KeyError: 'normMax'

# %%
de_text.head(20).index
# Out:
# Index(['TIMP1', 'MALAT1', 'MGP', 'MT-CO2', 'MT-CO1', 'MT-CYB', 'MT-CO3',
#        'MT-ATP6', 'MT-ND4', 'MT-ND3', 'TNC', 'MT-ND1', 'DCBLD2', 'MT-ND2',
#        'AREG', 'MT-ND5', 'TRIO', 'ADAMTSL1', 'EXT1', 'MACF1'],
#       dtype='object', name='features')

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
adata.obs["phate_tail_Cluster"] = adata.obs.phate_tail.astype(str) + adata.obs.Cluster.astype(str)

# %%
gene = "PPP1R1B"

# %%
plt.rcParams["figure.figsize"] = [10,3]
sc.pl.violin(adata, keys=gene, groupby="cluter_cond", rotation=90, jitter=0, layer="scvi_normalized", use_raw=False, multi_panel = True)

# %%
plt.rcParams["figure.figsize"] = [5,3]
sc.pl.violin(adata, keys=gene, groupby="condition", rotation=90, jitter=0.01, layer="scvi_normalized", use_raw=False)

# %%
plt.rcParams["figure.figsize"] = [5,3]
sc.pl.violin(adata, keys=gene, groupby="sample", rotation=90, jitter=0.01, layer="scvi_normalized", use_raw=False)

# %%
plt.rcParams["figure.figsize"] = [5,3]
sc.pl.umap(adata, color = gene, layer = "scvi_normalized", size = 10)

# %%
adata.obs["cluter_sample"] = adata.obs['Cluster'].astype(str) + "_" + adata.obs['sample'].astype(str)
adata.obs["cluter_cond"] = adata.obs['Cluster'].astype(str) + "_" + adata.obs['condition'].astype(str)

# %%
adata.obs.head()
# Out:
#                           orig.ident_cellbender  nCount_RNA_cellbender  \
# CTR01:AAGACAAGTGGTAATA-1                      0                69416.0
# CTR01:CTAGGTAAGATGGCAC-1                      0                68781.0
# CTR01:ACGGGTCTCAGCCTCT-1                      0                68161.0
# CTR01:CTCAACCCACGTATAC-1                      0                67943.0
# CTR01:CAACAACTCTCCCAAC-1                      0                67667.0
#
#                           nFeature_RNA_cellbender orig.ident_doubletFinder  \
# CTR01:AAGACAAGTGGTAATA-1                     6642                    CTR01
# CTR01:CTAGGTAAGATGGCAC-1                     6834                    CTR01
# CTR01:ACGGGTCTCAGCCTCT-1                     7320                    CTR01
# CTR01:CTCAACCCACGTATAC-1                     8743                    CTR01
# CTR01:CAACAACTCTCCCAAC-1                     6837                    CTR01
#
#                           nCount_RNA_doubletFinder  \
# CTR01:AAGACAAGTGGTAATA-1                   69416.0
# CTR01:CTAGGTAAGATGGCAC-1                   68781.0
# CTR01:ACGGGTCTCAGCCTCT-1                   68161.0
# CTR01:CTCAACCCACGTATAC-1                   67943.0
# CTR01:CAACAACTCTCCCAAC-1                   67667.0
#
#                           nFeature_RNA_doubletFinder  percent.mt  \
# CTR01:AAGACAAGTGGTAATA-1                      6642.0    0.191598
# CTR01:CTAGGTAAGATGGCAC-1                      6834.0    0.053794
# CTR01:ACGGGTCTCAGCCTCT-1                      7320.0    0.608853
# CTR01:CTCAACCCACGTATAC-1                      8743.0    2.590407
# CTR01:CAACAACTCTCCCAAC-1                      6837.0    0.016256
#
#                           percent.ribo  nCount_SCT  nFeature_SCT  ...  \
# CTR01:AAGACAAGTGGTAATA-1     23.774058     23651.0        3838.0  ...
# CTR01:CTAGGTAAGATGGCAC-1     21.078496     23730.0        4110.0  ...
# CTR01:ACGGGTCTCAGCCTCT-1     25.909244     23751.0        4596.0  ...
# CTR01:CTCAACCCACGTATAC-1     11.893793     25272.0        6234.0  ...
# CTR01:CAACAACTCTCCCAAC-1     25.177708     23690.0        3970.0  ...
#
#                           initial_size  Cluster   S_score G2M_score phase  \
# CTR01:AAGACAAGTGGTAATA-1       54592.0        9 -0.021989 -0.157879    G1
# CTR01:CTAGGTAAGATGGCAC-1       54125.0        7 -0.012820 -0.145869    G1
# CTR01:ACGGGTCTCAGCCTCT-1       49623.0        0  0.005373 -0.125073     S
# CTR01:CTCAACCCACGTATAC-1       33617.0        6 -0.032042 -0.162007    G1
# CTR01:CAACAACTCTCCCAAC-1       51165.0        7 -0.023015 -0.168176    G1
#
#                           phate_tail  _scvi_raw_norm_scaling  \
# CTR01:AAGACAAGTGGTAATA-1          no                0.230739
# CTR01:CTAGGTAAGATGGCAC-1          no                0.231267
# CTR01:ACGGGTCTCAGCCTCT-1          no                0.247611
# CTR01:CTCAACCCACGTATAC-1          no                0.229774
# CTR01:CAACAACTCTCCCAAC-1          no                0.226660
#
#                           phate_tail_Cluster  cluter_sample  cluter_cond
# CTR01:AAGACAAGTGGTAATA-1                 no9        9_CTR01        9_CTR
# CTR01:CTAGGTAAGATGGCAC-1                 no7        7_CTR01        7_CTR
# CTR01:ACGGGTCTCAGCCTCT-1                 no0        0_CTR01        0_CTR
# CTR01:CTCAACCCACGTATAC-1                 no6        6_CTR01        6_CTR
# CTR01:CAACAACTCTCCCAAC-1                 no7        7_CTR01        7_CTR
#
# [5 rows x 39 columns]

# %%
sc.pl.scatter(adata,x= "NDST1", y="NDST1-AS1", color="condition", size = 20)

# %%
 de_df.loc[(de_df['is_de_fdr_0.05'] == True) & (de_df['lfc_mean'] > 0 ), ].head(40).index
# Out:
# Index(['RBBP8NL', 'TIMP1', 'CST1', 'NLRP7', 'KISS1', 'CRIP2', 'CCL1',
#        'AC005358.2', 'KCNN4', 'DNAI2', 'AC076966.2', 'AC005682.2', 'PLA2G2A',
#        'IL23A', 'HES5', 'CYGB', 'AC147651.1', 'PMCH', 'TDRD15', 'CALY',
#        'AC093912.1', 'PNLDC1', 'NPPC', 'C2CD4B', 'SERPINA3', 'COMP', 'CRLF1',
#        'DCAF8L2', 'BTBD17', 'ELN', 'AC009154.1', 'CRYBB1', 'C12orf50', 'SSTR2',
#        'GADD45G', 'OTP', 'TINAGL1', 'AC010649.1', 'SPINK1', 'PAGE5'],
#       dtype='object', name='features')

# %%
plt.rcParams["figure.figsize"] = [8,10]
sc.pl.stacked_violin(adata,
                     var_names= de_df.loc[(de_df['is_de_fdr_0.05'] == True) & (de_df['lfc_mean'] > 0 ), ].head(40).index,
                     groupby="phate_tail_Cluster", swap_axes=True,
                    layer = "scvi_normalized", 
                    standard_scale = "var")

# %%
plt.rcParams["figure.figsize"] = [8,10]
sc.pl.stacked_violin(adata,
                     var_names=de_text.head(40).index,
                     groupby="phate_tail_Cluster", swap_axes=True,
                    layer = "scvi_normalized", 
                    standard_scale = "var")

# %%
plt.rcParams["figure.figsize"] = [6,4]
sc.pl.umap(adata, color="condition", size = 10, groups="SPR")

# %%
plt.rcParams["figure.figsize"] = [10,10]
sc.pl.stacked_violin(adata,
                     var_names=["MEF2C","TCF4","SOX5","SATB2"],
                     groupby="Cluster", swap_axes=True,
                    layer = "scvi_normalized")

# %%
plt.rcParams["figure.figsize"] = [10,10]
sc.pl.stacked_violin(adata,
                     var_names=de_text.head(20).index,
                     groupby="condition", swap_axes=True,
                    layer = "scvi_normalized")

# %%
marker_genes_dict = {
    'Adipocytes': ["HOXC8",'HOXC9'],
    'qNSC': ['CLU','ID3'],
    'aNSC': ['RPL32','EGFR'],
    'NSC': ['NES'],
    'Neurogenesis': ['SOX2','CENPF','HES1','NES'],
    'Astrocyte': ['AQP4','GFAP','EDNRB','GJA1'],
    'Excitatory': ['CUX2','RORB','TLE4'], 
    'Inhibitory' : ['PVALB', 'SST', 'SV2C', 'RELN', ],
    'Glial': ['PLP1','VCAN','SLC1A2','CSF1R']}

# %%
marker_genes_dict = {
    'Adipocytes': ["HOXC8",'HOXC9'],
    'qNSC': ['CLU','ID3'],
    'aNSC': ['RPL32','EGFR'],
    'NSC': ['NES'],
    'Neurogenesis': ['SOX2','CENPF','HES1','NES'],
    'Astrocyte': ['AQP4','GFAP','EDNRB','GJA1']}

# %%
sc.pl.dotplot(adata, marker_genes_dict, groupby="Cluster", dendrogram=True)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_Cluster). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: You’re trying to run this on 10000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0, 1, 2, etc.
# var_group_labels: Adipocytes, qNSC, aNSC, etc.

# %%
marker_genes_dict = {
    'SPR vs CTR': ['SLC35F1','BST2','LERFS','ECHDC3','MTRNR2L1','MT-ND6','CCL18','NKD2','NPAS3','ADAMTSL3','SCHLAP1','AC109466.1','SNTG1','MT-ATP8','ROPN1','SLC40A1'],
    'GHR vs CTR ': ['PPP1R1B','SLC35F1','LERFS','NKD2','APOD','AC109466.1','SCHLAP1'],
    'SPR vs GHR' : ['NDST1-AS1','MORN4','LINC02109','MT-ND6']}

# %%
sc.pl.dotplot(adata, marker_genes_dict, groupby="cluter_cond",standard_scale = 'var', dendrogram=True)
# Out:
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: 0_CTR, 0_GHR, 0_SPR, etc.
# var_group_labels: SPR vs CTR, GHR vs CTR , SPR vs GHR

# %%
sc.pl.umap(adata, color = "Cluster", groups="13")

# %%
plt.rcParams["figure.figsize"] = [3,4]
tmp = pd.crosstab(adata.obs['phate_tail'],adata.obs['sample'], normalize='index')
tmp.plot.bar(stacked=True).legend(loc='center left', bbox_to_anchor=(1, 0.5))
